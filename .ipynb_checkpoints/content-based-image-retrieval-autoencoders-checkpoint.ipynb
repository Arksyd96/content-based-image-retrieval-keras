# %% [markdown]
# # **Imports:**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow.keras.backend as K
from PIL import Image
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Reshape
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, BatchNormalization
from tensorflow.keras.layers import DepthwiseConv2D
from tensorflow.keras.layers import LeakyReLU

# %% [markdown]
# # **Data preprocessing** (Using CIFAR10 dataset)

# %%
# Loading data from cifar10 dataset
(train_x, train_y), (test_x, test_y) = cifar10.load_data()

# normilizing data to [0 - 1]
train_x = train_x.astype("float32") / 255.0
test_x = test_x.astype("float32") / 255.0

# %% [markdown]
# # **Creating the autoencoder:**

# %% [markdown]
# ### Encoder:

# %%
latentDim = 512

encoderInput = Input(shape=(32, 32, 3))

X = Conv2D(32, (3, 3), strides=2, padding="same")(encoderInput)
X = BatchNormalization(axis=-1)(X)
X = LeakyReLU(alpha=0.3)(X)

X = DepthwiseConv2D((3, 3), strides=2, padding="same")(X)
X = BatchNormalization(axis=-1)(X)
X = LeakyReLU(alpha=0.3)(X)

X = Conv2D(64, (3, 3), strides=2, padding="same")(X)
X = BatchNormalization(axis=-1)(X)
X = LeakyReLU(alpha=0.3)(X) 

volumeSize = K.int_shape(X)
X = Flatten()(X)
X = Dense(latentDim)(X)

encoder = Model(encoderInput, X, name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_13 (InputLayer)        [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 16, 16, 32)        896
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 16, 16, 32)        0
# _________________________________________________________________
# depthwise_conv2d_4 (Depthwis (None, 8, 8, 32)          320
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 8, 8, 32)          128
# _________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)   (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 4, 4, 64)          18496
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 4, 4, 64)          256
# _________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)   (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               524800
# =================================================================
# Total params: 545,024
# Trainable params: 544,768
# Non-trainable params: 256
# _________________________________________________________________

# %% [markdown]
# ### Decoder:

# %%
decoderInput = Input(shape=(latentDim,))
X = Dense(np.prod(volumeSize[1:]))(decoderInput)
X = Reshape((volumeSize[1], volumeSize[2], volumeSize[3]))(X)

X = Conv2DTranspose(64, (3, 3), strides=2, padding="same")(X)
X = BatchNormalization(axis=-1)(X)
X = LeakyReLU(alpha=0.3)(X)

X = Conv2DTranspose(32, (3, 3), strides=2, padding="same")(X)
X = BatchNormalization(axis=-1)(X)
X = LeakyReLU(alpha=0.3)(X)

X = Conv2DTranspose(32, (3, 3), strides=2, padding="same")(X)
X = BatchNormalization(axis=-1)(X)
X = LeakyReLU(alpha=0.3)(X)

X = Conv2DTranspose(3, (3, 3), padding="same", activation="sigmoid")(X)

decoder = Model(decoderInput, X, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_14 (InputLayer)        [(None, 512)]             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_transpose_11 (Conv2DT (None, 8, 8, 64)          36928
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 8, 8, 64)          256
# _________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)   (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_transpose_12 (Conv2DT (None, 16, 16, 32)        18464
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)   (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_transpose_13 (Conv2DT (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_transpose_14 (Conv2DT (None, 32, 32, 3)         867
# =================================================================
# Total params: 591,331
# Trainable params: 591,075
# Non-trainable params: 256
# _________________________________________________________________

# %% [markdown]
# ### Autoencoder:

# %%
autoencoder = Model(encoderInput, decoder(encoder(encoderInput)), name="autoencoder")
autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_13 (InputLayer)        [(None, 32, 32, 3)]       0
# _________________________________________________________________
# encoder (Model)              (None, 512)               545024
# _________________________________________________________________
# decoder (Model)              (None, 32, 32, 3)         591331
# =================================================================
# Total params: 1,136,355
# Trainable params: 1,135,843
# Non-trainable params: 512
# _________________________________________________________________

# %% [markdown]
# # **Training:**

# %%
autoencoder.compile(loss="mse", optimizer="adam")

history = autoencoder.fit(train_x, train_x,
               validation_data=(test_x, test_x),
               epochs=20,
               batch_size=32)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 112s 2ms/sample - loss: 0.0092 - val_loss: 0.0048
# Epoch 2/20
# 50000/50000 [==============================] - 37s 749us/sample - loss: 0.0050 - val_loss: 0.0045
# Epoch 3/20
# 50000/50000 [==============================] - 38s 760us/sample - loss: 0.0041 - val_loss: 0.0034
# Epoch 4/20
# 50000/50000 [==============================] - 38s 761us/sample - loss: 0.0036 - val_loss: 0.0031
# Epoch 5/20
# 50000/50000 [==============================] - 38s 751us/sample - loss: 0.0032 - val_loss: 0.0026
# Epoch 6/20
# 50000/50000 [==============================] - 38s 753us/sample - loss: 0.0029 - val_loss: 0.0023
# Epoch 7/20
# 50000/50000 [==============================] - 39s 774us/sample - loss: 0.0027 - val_loss: 0.0024
# Epoch 8/20
# 50000/50000 [==============================] - 38s 760us/sample - loss: 0.0026 - val_loss: 0.0022
# Epoch 9/20
# 50000/50000 [==============================] - 38s 760us/sample - loss: 0.0024 - val_loss: 0.0021
# Epoch 10/20
# 50000/50000 [==============================] - 38s 767us/sample - loss: 0.0023 - val_loss: 0.0020
# Epoch 11/20
# 50000/50000 [==============================] - 38s 761us/sample - loss: 0.0022 - val_loss: 0.0019
# Epoch 12/20
# 50000/50000 [==============================] - 38s 759us/sample - loss: 0.0021 - val_loss: 0.0018
# Epoch 13/20
# 50000/50000 [==============================] - 39s 771us/sample - loss: 0.0020 - val_loss: 0.0018
# Epoch 14/20
# 50000/50000 [==============================] - 39s 785us/sample - loss: 0.0020 - val_loss: 0.0017
# Epoch 15/20
# 50000/50000 [==============================] - 39s 775us/sample - loss: 0.0019 - val_loss: 0.0017
# Epoch 16/20
# 50000/50000 [==============================] - 38s 756us/sample - loss: 0.0019 - val_loss: 0.0017
# Epoch 17/20
# 50000/50000 [==============================] - 39s 788us/sample - loss: 0.0018 - val_loss: 0.0016
# Epoch 18/20
# 50000/50000 [==============================] - 39s 778us/sample - loss: 0.0018 - val_loss: 0.0016
# Epoch 19/20
# 50000/50000 [==============================] - 39s 774us/sample - loss: 0.0017 - val_loss: 0.0015
# Epoch 20/20
# 50000/50000 [==============================] - 39s 773us/sample - loss: 0.0017 - val_loss: 0.0016

# %%
plt.figure()
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper right")

# %% [markdown]
# ## Reconstructing some images :

# %%
decoded = autoencoder.predict(train_x)

plt.figure(figsize=(10,10))
for i in range(0, 10):
    original = (train_x[i] * 255).astype("uint8")
    recon = (decoded[i] * 255).astype("uint8")
    plt.subplot(10, 1, i + 1)
    plt.imshow(np.hstack(np.squeeze([original, recon])))
    plt.axis("off")
plt.show()

# %% [markdown]
# # **Saving model:**

# %%
# serialize model to JSON
model_json = autoencoder.to_json()
with open("cbir-autoencoder.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
autoencoder.save_weights("cbir-autoencoder.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# # Getting the latent-space of each image:
# ### We'll compare each latent-space with the query (euclidean distance)

# %%
features = encoder.predict(train_x)
queryIndex = np.random.randint(len(train_x))
query = features[queryIndex]
max_results = 20
results = []

for i in range(0, len(train_x)):
    delta = np.linalg.norm(query - features[i])
    results.append((delta, i))
    
results = sorted(results)[:max_results]

# %% [markdown]
# ### Ploting results:

# %%
plt.imshow((train_x[queryIndex] * 255).astype("uint"))

# %%
plt.figure(figsize=(10, 10))
for i in range(0, len(results)):
    plt.subplot(4, 5, i + 1)
    plt.imshow((train_x[results[i][1]] * 255).astype("uint8"))
    plt.axis("off")
plt.show()
